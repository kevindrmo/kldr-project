# %% [markdown]
# ## Import the dataframe and do a copy

# %%
# import all relevant libraries --> can't use utils since it is a jupyter notebook
import streamlit as st
import pandas as pd
from pathlib import Path
import plotly.express as px

ROOT = Path(__file__).parent.parent

df_raw = pd.read_csv(ROOT/"data"/ "UNCTAD_DE_WIDEF.csv")

df = df_raw.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 from pathlib import Path
#       5 import plotly.express as px
# ----> 7 ROOT = Path(__file__).parent.parent
#       9 df_raw = pd.read_csv(ROOT/"data"/ "UNCTAD_DE_WIDEF.csv")
#      11 df = df_raw.copy()
#
# NameError: name '__file__' is not defined
