# %%
# import all relevant libraries --> can't use utils since it is a jupyter notebook
import streamlit as st
import pandas as pd
from pathlib import Path
import plotly.express as px
import numpy as np
from linearmodels.panel import PanelOLS, compare

# %%
# --- Use your established path definitions ---
CWD = Path.cwd()
ROOT = CWD.parent

IN_RAW = ROOT / "app" / "data" / "output" / "question1" # Corrected to point to question1
OUT_CLEAN = ROOT / "app" / "data" / "output"
OUT_TABLES = ROOT / "app" / "data" / "tables"
OUT_QUESTION2 = ROOT / "app" / "data" / "output" / "question2p_paneldata"

# Create directories
IN_RAW.mkdir(parents=True, exist_ok=True)
OUT_CLEAN.mkdir(parents=True, exist_ok=True)
OUT_TABLES.mkdir(parents=True, exist_ok=True)
OUT_QUESTION2.mkdir(parents=True, exist_ok=True) # For saving the new results

print(f"Project Root: {ROOT}")
print(f"Data Input Path: {IN_RAW}")
print(f"Panel Data Output Path: {OUT_QUESTION2}")
# Out:
# Project Root: c:\Users\dirai\Documents\GitHub\kldr-project
# Data Input Path: c:\Users\dirai\Documents\GitHub\kldr-project\app\data\output\question1
# Panel Data Output Path: c:\Users\dirai\Documents\GitHub\kldr-project\app\data\output\question2p_paneldata

# %%
df_panel = pd.read_csv(IN_RAW/"final_panel_for_regression.csv")

df_panel = df_panel.set_index(["country_code", "year"])


# Define dependent and independent variables
Y = np.log(df_panel['Exports_Digital_Service'] + 1)
X = df_panel[['internet_usage_pct', 'gdp_per_capita', 'population']]
X['log_gdp_per_capita'] = np.log(X['gdp_per_capita'] + 1)
X['log_population'] = np.log(X['population'] + 1)
X = X[['internet_usage_pct', 'log_gdp_per_capita', 'log_population']]

# Add a constant for the Pooled OLS model
from statsmodels.api import add_constant
X_pooled = add_constant(X)

print("Data prepared for Panel Data Analysis.")
# Out:
# C:\Users\dirai\AppData\Local\Temp\ipykernel_30684\1295798779.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['log_gdp_per_capita'] = np.log(X['gdp_per_capita'] + 1)
# C:\Users\dirai\AppData\Local\Temp\ipykernel_30684\1295798779.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['log_population'] = np.log(X['population'] + 1)
# Data prepared for Panel Data Analysis.

# %%
# --- 1. Pooled OLS (the baseline, flawed model) ---
mod_pooled = PanelOLS(Y, X_pooled)
res_pooled = mod_pooled.fit()

# --- 2. Country Fixed Effects Model ---
# We add `entity_effects=True` to control for each country
mod_fe = PanelOLS(Y, X, entity_effects=True)
res_fe = mod_fe.fit()

# --- 3. Two-way Fixed Effects Model (Country + Time) ---
# We add `time_effects=True` to also control for global year-shocks
mod_twfe = PanelOLS(Y, X, entity_effects=True, time_effects=True)
res_twfe = mod_twfe.fit()

print("All three models have been estimated.")
# Out:
# All three models have been estimated.

# %%
from linearmodels.panel import compare

# --- Create the comparison dictionary ---
results_dict = {
    "Standard OLS": res_pooled, # Changed from "Pooled OLS"
    "Country FE": res_fe,
    "Two-way FE": res_twfe
}

# --- Generate the comparison table object ---
comparison_table = compare(results_dict)

# --- THIS IS THE CHANGE: SAVE AS A TEXT FILE ---

# 1. Convert the comparison table object to a string
table_as_string = str(comparison_table)

# 2. Define the output path with a .txt extension
comparison_txt_path = OUT_QUESTION2 / "panel_models_comparison.txt" # <-- Changed to .txt

# 3. Write the string to the new text file.
with open(comparison_txt_path, "w") as f:
    f.write(table_as_string)

print(f"\nComparison table saved as a text file to: {comparison_txt_path}")

# Display the original table object in the notebook to check it
comparison_table
# Out:
# Comparison table saved as a text file to: c:\Users\dirai\Documents\GitHub\kldr-project\app\data\output\question2p_paneldata\panel_models_comparison.txt
#                                               Model Comparison
# ...
#                                        Standard OLS                  Country FE                  Two-way FE
# -----------------------------------------------------------------------------------------------------------
# Dep. Variable               Exports_Digital_Service     Exports_Digital_Service     Exports_Digital_Service
# Estimator                                  PanelOLS                    PanelOLS                    PanelOLS
# No. Observations                               2367                        2367                        2367
# Cov. Est.                                Unadjusted                  Unadjusted                  Unadjusted
# R-squared                                    0.6306                      0.0236                      0.0061
# ...

# %%
# --- Create a DataFrame for our interactive plot ---
# We will extract the coefficients and confidence intervals for each model

plot_data = []
for model_name, model_results in results_dict.items():
    for var in model_results.params.index:
        if var == 'const': continue # Skip the constant
        
        plot_data.append({
            'Model': model_name,
            'Variable': var,
            'Coefficient': model_results.params[var],
            'Conf. Lower': model_results.conf_int().loc[var, 'lower'],
            'Conf. Upper': model_results.conf_int().loc[var, 'upper']
        })

plot_df = pd.DataFrame(plot_data)

# --- Save this data to a new CSV file ---
# We'll save it in the same output folder
plot_data_path = OUT_QUESTION2 / "panel_plot_data.csv"
plot_df.to_csv(plot_data_path, index=False)

print(f"\nData for interactive plot saved to: {plot_data_path}")
plot_df
# Out:
# Data for interactive plot saved to: c:\Users\dirai\Documents\GitHub\kldr-project\app\data\output\question2p_paneldata\panel_plot_data.csv
#         Model            Variable  Coefficient  Conf. Lower  Conf. Upper
# 0  Pooled OLS  internet_usage_pct     0.010889     0.004941     0.016837
# 1  Pooled OLS  log_gdp_per_capita     1.466592     1.338422     1.594761
# 2  Pooled OLS      log_population     1.157556     1.111224     1.203887
# 3  Country FE  internet_usage_pct     0.009927     0.005217     0.014637
# 4  Country FE  log_gdp_per_capita     0.696363     0.232963     1.159762
# 5  Country FE      log_population    -0.561028    -1.407419     0.285363
# 6  Two-way FE  internet_usage_pct    -0.000335    -0.006962     0.006292
# 7  Two-way FE  log_gdp_per_capita     0.359840    -0.139210     0.858890
# 8  Two-way FE      log_population    -1.377054    -2.330047    -0.424060

# %%
# --- Function to create a summary DataFrame from a model result
def create_summary_df(model_results, model_name):
    # Extract main coefficients and p-values
    summary = pd.DataFrame({
        'Variable': model_results.params.index,
        'Coefficient': model_results.params.values,
        'P-Value': model_results.pvalues.values
    })
    
    # Add model's R-squared as a new row
    # We use R-squared for Pooled OLS and R-squared (Within) for FE models
    if model_name == 'Pooled OLS':
        r_squared = model_results.rsquared
    else:
        r_squared = model_results.rsquared_within
        
    r_squared_row = pd.DataFrame([{'Variable': 'R-Squared', 'Coefficient': r_squared, 'P-Value': 0}])
    
    # Combine and add the model name
    final_df = pd.concat([summary, r_squared_row], ignore_index=True)
    final_df['Model'] = model_name
    
    return final_df

# --- Create and save a summary for each model ---
df_ols_summary = create_summary_df(res_pooled, "Standard OLS") 
df_fe_summary = create_summary_df(res_fe, "Country FE")
df_twfe_summary = create_summary_df(res_twfe, "Two-way FE")

# --- Save them to your output directory ---
# CHANGE THE FILENAME HERE
df_ols_summary.to_csv(OUT_QUESTION2 / "summary_standard_ols.csv", index=False) 
df_fe_summary.to_csv(OUT_QUESTION2 / "summary_country_fe.csv", index=False)
df_twfe_summary.to_csv(OUT_QUESTION2 / "summary_twfe.csv", index=False)

print(f"Individual model summary files saved to: {OUT_QUESTION2}")
# Out:
# Individual model summary files saved to: c:\Users\dirai\Documents\GitHub\kldr-project\app\data\output\question2p_paneldata
